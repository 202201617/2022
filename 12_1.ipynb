# %% [markdown]
# <a href="https://colab.research.google.com/github/202201617/2022/blob/main/12_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Module(모듈): 함수, 변수, 클래스를 모아 놓은 파일

#module: math
import math

print(math.sin(1))
print(math.cos(1))
print(math.ceil(1.5))
print(math.floor(1.5))

#round는 정수가 홀수일 때 올리고, 정수가 짝수일 때 내림
#round는 반올림 함수가 아님 → 사용할 일이 거의 없음
print(round(1.5))
print(round(2.5))

#from 모듈 이름 import 가져오고 싶은 함수 또는 변수
from math import sin, cos, tan, floor, ceil

#from 모듈 이름 import * (모듈 내부의 모든 것을 다 가져옴)
# → 식별자 이름에서 충돌 발생할 수 있음
# → 최대한 필요한 것만 가져와서 사용하는 것이 좋음

#import 모듈이름 as 사용하고 싶은 식별자
import math as m
print(m.sin(1))
print(m.cos(1))
print(m.ceil(1.5))
print(m.floor(1.5))
# Out:
# 0.8414709848078965
# 0.5403023058681398
# 2
# 1
# 2
# 2
# 0.8414709848078965
# 0.5403023058681398
# 2
# 1

# %%
#module: random
import random as rn

#random(): 0 <= x < 1 사이의 float로 리턴
print(rn.random())

#uniform(min, max): 지정한 범위 사이의 float를 리턴
print(rn.uniform(0, 10))

#randrange(): 지정한 범위의 int를 리턴
print(rn.randrange(0, 10))

#choice(list): 리스트 내부 요소를 랜덤하게 선택
print(rn.choice([1,2,3,4,5]))

#shuffle(list): 리스트 내부 요소를 랜덤하게 섞음
a = [1,2,3,4,5]
rn.shuffle(a)
print(a)

#sample(list, k=숫자):
print(rn.sample([1,2,3,4,5], 2))
# Out:
# 0.26938103110249334
# 6.175584799059638
# 6
# 3
# [4, 1, 2, 3, 5]
# [3, 2]

# %%
#module: os
#colab에서 google drive와 연결
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/2023-1st/')

print(os.name) #현재 운영체제
print(os.getcwd()) #현재 폴더
print(os.listdir()) #현재 폴더 내부요소

#폴더 제거하고 만들기
os.mkdir('New_folder')
os.rmdir('New_folder')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# posix
# /content/drive/MyDrive/2023-1st
# ['전산수학 1-1.ipynb', '전산수학 과제(3 10)', '전산수학 1-2', '전산수학 2-1', '전산수학 2-2', '전산수학 4-1', '전산수학 3-1', '전산수학 3-2', '전산수학 4-2', '전산수학 5-1', '전산수학 7-2', 'Newfile.txt', 'lotto.txt', 'Newfile2.txt', 'Newfile3.txt', 'data.csv', 'data2.csv', '전산수학 10-1.ipynb', '전산수학 9-2', '전산수학 11-1', 'Untitled15.ipynb', 'dd', 'New_folder']
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-29-a2cb5e5cbf9a> in <cell line: 14>()
#      12
#      13 #폴더 제거하고 만들기
# ---> 14 os.mkdir('New_folder')
#      15 os.rmdir('New_folder')
#
# FileExistsError: [Errno 17] File exists: 'New_folder'

# %%
#파일을 생성하고 파일 이름을 변경
with open('test10.txt', 'w') as f:
  f.write('지금은 테스트 중입니다.')

os.rename('test10.txt', 'new.txt')

#파일 제거하기
os.remove('new.txt')
#os.unlink('new.txt') #어느 것을 사용해도 무방함

#현재 디렉터리를 읽어들이고 디렉터리(폴더)인지 구분하기
output = os.listdir()
for item in output:
  if os.path.isdir(item):
    print('폴더:', item)
  else:
    print('파일:', item)
print('='*20)

#폴더의 요소 읽어들이기
def reader_folder(path):
  output = os.listdir(path)
  for item in output:
    if os.path.isdir(item):
      reader_folder(item)
    else:
      print('파일:', item)


print(os.getcwd())

os.mkdir('New_folder5')
file_path = '/content/drive/MyDrive/2023-1st/New_folder5/test5.txt'
with open(os.path.join(file_path), 'w') as f:
  f.write('지금은 테스트 중 입니다')

reader_folder('.')
# Out:
# 파일: 전산수학 1-1.ipynb
# 파일: 전산수학 과제(3 10)
# 파일: 전산수학 1-2
# 파일: 전산수학 2-1
# 파일: 전산수학 2-2
# 파일: 전산수학 4-1
# 파일: 전산수학 3-1
# 파일: 전산수학 3-2
# 파일: 전산수학 4-2
# 파일: 전산수학 5-1
# 파일: 전산수학 7-2
# 파일: Newfile.txt
# 파일: lotto.txt
# 파일: Newfile2.txt
# 파일: Newfile3.txt
# 파일: data.csv
# 파일: data2.csv
# 파일: 전산수학 10-1.ipynb
# 파일: 전산수학 9-2
# 파일: 전산수학 11-1
# 파일: Untitled15.ipynb
# 폴더: dd
# 폴더: New_folder2
# 폴더: New_folder3
# 폴더: New_folder4
# ====================
# /content/drive/MyDrive/2023-1st
# 파일: 전산수학 1-1.ipynb
# 파일: 전산수학 과제(3 10)
# 파일: 전산수학 1-2
# 파일: 전산수학 2-1
# 파일: 전산수학 2-2
# 파일: 전산수학 4-1
# 파일: 전산수학 3-1
# 파일: 전산수학 3-2
# 파일: 전산수학 4-2
# 파일: 전산수학 5-1
# 파일: 전산수학 7-2
# 파일: Newfile.txt
# 파일: lotto.txt
# 파일: Newfile2.txt
# 파일: Newfile3.txt
# 파일: data.csv
# 파일: data2.csv
# 파일: 전산수학 10-1.ipynb
# 파일: 전산수학 9-2
# 파일: 전산수학 11-1
# 파일: Untitled15.ipynb
# 파일: d.gdoc
# 파일: test5.txt

# %%
#module: urllib 모듈
from urllib import request

#urlopen()함수로 링크 열기
target = request.urlopen('https://google.com')
output = target.read()
print(output)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="wftEoEK3CKVtY-6z5_PScQ">(function(){window.google={kEI:\'gc5mZK7lGMu5qtsPx5i-2AY\',kEXPI:\'0,1359409,6058,207,4804,2316,383,246,5,1129120,1704,1196004,693,380090,16114,19397,9287,22430,1362,12318,2816,14765,4998,13228,3847,6885,31559,2872,2891,3926,7828,606,29843,30847,15324,781,1244,1,16916,2652,4,1528,2304,13383,15679,13064,13659,2980,18243,5821,2536,4097,7593,1,42154,2,14022,2373,342,23024,5679,1021,31122,4568,6252,23424,1252,5835,14968,4332,7484,445,2,2,1,26632,8155,7381,2,3,15964,873,7830,1796,10008,8,1921,9779,36154,6305,2007,18191,20137,14,82,16514,3692,109,2412,5856,3785,15203,5375,2265,765,6110,5041,4665,1804,6249,1485,2738,2885,10073,2402,1261,6004,2171,961,7826,2365,662,1252,182,87,113,2481,5468,217,674,3576,1275,167,584,545,3147,2756,1441,425,245,616,666,4,921,1491,66,1,84,599,2608,3214,208,343,129,1710,2149,682,1,1072,9,4669,943,599,530,538,8,3,13,290,823,268,919,1624,696,643,319,44,214,51,134,198,644,464,601,372,1209,2,10,534,20,5202602,11,6268,556,46,85,2,8798154,3311,141,795,19735,1,1,346,5095,46,553,83,80,109,26,13,11,15,23944454,4042142,1964,1008,13289,2376,2893,6250,14715,1024,4195,1678,1409184,260490,23498777,686,83,94,134,816,752,1,441,87,508,2,440,25,82,766,105,156,2,1011,129,1,503,5,1,201,267,188,333,364,92,2129,64,401,4,493,620,179,427,23,186,108,314,80,74,1793,1294,280,2,493,85,123,360,269,50,173,263,1,7,190,283,450,9,263,464,172,61,428,5,1010,3,1319,1725,149,648,5,196,1145,108,59,450,2,543,745,213\',kBL:\'VVNZ\',kOPI:89978449};google.sn=\'webhp\';google.kHL=\'en\';})();(function(){\nvar h=this||self;function l(){return void 0!==window.google&&void 0!==window.google.kOPI&&0!==window.google.kOPI?window.google.kOPI:null};var m,n=[];function p(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||m}function q(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function r(a){/^http:/i.test(a)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}\nfunction t(a,b,c,d,k){var e="";-1===b.search("&ei=")&&(e="&ei="+p(d),-1===b.search("&lei=")&&(d=q(d))&&(e+="&lei="+d));d="";var g=-1===b.search("&cshid=")&&"slh"!==a,f=[];f.push(["zx",Date.now().toString()]);h._cshid&&g&&f.push(["cshid",h._cshid]);c=c();null!=c&&f.push(["opi",c.toString()]);for(c=0;c<f.length;c++){if(0===c||0<c)d+="&";d+=f[c][0]+"="+f[c][1]}return"/"+(k||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+d)};m=google.kEI;google.getEI=p;google.getLEI=q;google.ml=function(){return null};google.log=function(a,b,c,d,k,e){e=void 0===e?l:e;c||(c=t(a,b,e,d,k));if(c=r(c)){a=new Image;var g=n.length;n[g]=a;a.onerror=a.onload=a.onabort=function(){delete n[g]};a.src=c}};google.logUrl=function(a,b){b=void 0===b?l:b;return t("",a,b)};}).call(this);(function(){google.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.d ...

# %%
#BeautifulSoup
#Beautiful Soup is Python library for pulling data
#out of HTML and XML files

from urllib import request
from bs4 import BeautifulSoup

#urlopen() 함수로 기상청의 전국날씨 읽기
target = request.urlopen('https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnld=108')

#BeautifulSoup을 사용해 웹페이지를 분석 (parser: 문장의 구조 분석·오류 점검 프로그램)
soup = BeautifulSoup(target, 'html.parser')

#location 태그를 찾음 / select() 함수는 여러개를 선택 / select_one() 함수는 원하는 값을 추출
for location in soup.select('location'):
  print('도시:', location.select_one('city').string)
  print('날씨:', location.select_one('wf').string)
  print('최저기온:', location.select_one('tmn').string)
  print('최고기온:', location.select_one('tmx').string)
  print()
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# 도시: 서울
# 날씨: 구름많음
# 최저기온: 14
# 최고기온: 25
#
# 도시: 인천
# 날씨: 구름많음
# 최저기온: 14
# 최고기온: 22
#
# 도시: 수원
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 24
#
# 도시: 파주
# 날씨: 구름많음
# 최저기온: 12
# 최고기온: 25
#
# 도시: 이천
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 24
#
# 도시: 평택
# 날씨: 구름많음
# 최저기온: 14
# 최고기온: 24
#
# 도시: 춘천
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 24
#
# 도시: 원주
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 23
#
# 도시: 강릉
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 22
#
# 도시: 대전
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 23
#
# 도시: 세종
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 24
#
# 도시: 홍성
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 23
#
# 도시: 청주
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 24
#
# 도시: 충주
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 23
#
# 도시: 영동
# 날씨: 구름많음
# 최저기온: 11
# 최고기온: 22
#
# 도시: 광주
# 날씨: 구름많음
# 최저기온: 14
# 최고기온: 22
#
# 도시: 목포
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 20
#
# 도시: 여수
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 20
#
# 도시: 순천
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 21
#
# 도시: 광양
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 22
#
# 도시: 나주
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 22
#
# 도시: 전주
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 23
#
# 도시: 군산
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 22
#
# 도시: 정읍
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 22
#
# 도시: 남원
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 22
#
# 도시: 고창
# 날씨: 구름많음
# 최저기온: 12
# 최고기온: 22
#
# 도시: 무주
# 날씨: 구름많음
# 최저기온: 11
# 최고기온: 22
#
# 도시: 부산
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 22
#
# 도시: 울산
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 21
#
# 도시: 창원
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 22
#
# 도시: 진주
# 날씨: 구름많음
# 최저기온: 14
# 최고기온: 22
#
# 도시: 거창
# 날씨: 구름많음
# 최저기온: 12
# 최고기온: 21
#
# 도시: 통영
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 21
#
# 도시: 대구
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 22
#
# 도시: 안동
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 22
#
# 도시: 포항
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 20
#
# 도시: 경주
# 날씨: 구름많음
# 최저기온: 14
# 최고기온: 20
#
# 도시: 울진
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 19
#
# 도시: 울릉도
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 19
#
# 도시: 제주
# 날씨: 흐림
# 최저기온: 16
# 최고기온: 19
#
# 도시: 서귀포
# 날씨: 흐림
# 최저기온: 16
# 최고기온: 20
#
# ['서귀포']

# %%
import csv

data = []
keys = ['도시', '날씨', '최저기온', '최고기온']
data.append(keys)

for location in soup.select('location'):
  row = []
  row.append(location.select_one('city').string)
  row.append(location.select_one('wf').string)
  row.append(location.select_one('tmn').string)
  row.append(location.select_one('tmx').string)
  data.append(row)

f = open('kma.csv', 'w')
g = csv.writer(f)
g.writerows(data)
f.close()
